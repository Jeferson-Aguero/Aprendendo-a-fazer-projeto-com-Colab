# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeferson-Aguero/Aprendendo-a-fazer-projeto-com-Colab/blob/main/Colab_primeiro_Projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8f6cb502-3516-4e3d-a3a3-702919cbfbbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f6cb502-3516-4e3d-a3a3-702919cbfbbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('planilha_satisfacao_clientes3.csv', sep=';', encoding='latin1')
df.head()
# Out:
#          Data  Nome do Cliente           Produto        Região  \
# 0  17/03/2025  Marcos Vinícius          Notebook           Sul
# 1  22/03/2025       João Silva           Monitor       Sudeste
# 2  28/04/2025      Rafael Dias  Teclado Mecânico       Sudeste
# 3  10/03/2025   Paulo Henrique    Fone Bluetooth      Nordeste
# 4  27/03/2025   Paulo Henrique    Fone Bluetooth  Centro-Oeste
#
#    Nota de Satisfação                  Comentário Valor da Compra
# 0                   4          Poderia ser melhor        R$270.14
# 1                   5           Atendimento ótimo        R$613.10
# 2                   3           Atendimento ótimo      R$2,309.85
# 3                   3     Satisfeito com a compra      R$1,506.50
# 4                   5  Produto chegou com defeito        R$550.58

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Nota de Satisfação'] = pd.to_numeric(df['Nota de Satisfação'], errors='coerce')

df['Valor da Compra'] = df['Valor da Compra'].str.replace('R$', '', regex=False)
df['Valor da Compra'] = df['Valor da Compra'].str.replace('.', '', regex=False)
df['Valor da Compra'] = df['Valor da Compra'].str.replace(',', '.', regex=False)
df['Valor da Compra'] = pd.to_numeric(df['Valor da Compra'], errors='coerce')

# %%
df.groupby('Região')['Nota de Satisfação'].mean()

# Visualizar os dados em gráfico
plt.figure(figsize=(10, 6))
sns.barplot(x=nota_por_produto.values, y=nota_por_produto.index, palette='coolwarm')
plt.title('Nota Média de Satisfação por Produto')
plt.xlabel('Nota Média')
plt.ylabel('Produto')
plt.xlim(0, 5)  # notas variam de 1 a 5
plt.show()
# Out:
# <ipython-input-33-7c2c829f8be0>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=nota_por_produto.values, y=nota_por_produto.index, palette='coolwarm')
